# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### list
# - append()
# - extend()
# - count()
# - index()
# - sort()
# - sorted()

# %%
a = [1,8,4]
b = sorted(a)
print(a)
print(b)
# Out:
# [1, 8, 4]
# [1, 4, 8]

# %%
#insert(index,element)

a = [1,10,5,4,3,6]
a.insert(3,7)
print(a)
# Out:
# [1, 10, 5, 7, 4, 3, 6]

# %%
a = [1,10,5,4,3,6]
a[3] = 9
print(a)
# Out:
# [1, 10, 5, 9, 3, 6]

# %%
#pop(position) ->returns  the popped element
a.pop()
print(a)
# Out:
# [1, 10, 5, 9, 3]

# %%
a.pop(0)
print(a)
# Out:
# [10, 5, 9, 3]

# %%
#remove(value) -> removes the first occurence of that given value

# %%
a = [1,[7,[[[1,"h"]],9],8],5]

# %%
a[1][2]
# Out:
# 8

# %%
a = [1,5,7,2,0,9,4,6,8,10]
# a[start:end] -> slicing this returns a list
# if starting index is not specified starts for the 0th index
a[4:]
# Out:
# [0, 9, 4, 6, 8, 10]

# %% [markdown]
# ### a[start:end:step]

# %%
a[4:]
# Out:
# [0, 9, 4, 6, 8, 10]

# %%
a[1:8:2]
# Out:
# [5, 2, 9, 6]

# %%
a[::-1] #reverse the string
# Out:
# [10, 8, 6, 4, 9, 0, 2, 7, 5, 1]

# %% [markdown]
# string is immutable ,we cant change a string

# %% [markdown]
# ## Dictionary

# %%
a = {
    "name":"dev",
    "age":22,
    "sex":"male"
}

# %%
print(a)
# Out:
# {'name': 'dev', 'age': 22, 'sex': 'male'}

# %%
a["name"]
# Out:
# 'dev'

# %%
a.get("name") #return the value of te given key
# Out:
# 'dev'

# %%
print(a.get("mark"))
# Out:
# None

# %%
print(a.get("state","kl")) # if we pass the default vlue with key in get we dont get none insead we get the default value
# Out:
# kl

# %%
a.get("name","raju") # we pass the default vlue with already exiting key, we get the real value
# Out:
# 'dev'
